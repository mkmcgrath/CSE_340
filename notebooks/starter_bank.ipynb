# %%
import pandas as pd

campaign = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')

# %%
# Out:
#        age            job  marital          education  default  housing  \
# 3503    28    blue-collar  married           basic.9y       no       no
# 3211    29    blue-collar   single        high.school       no      yes
# 27774   44   entrepreneur  married           basic.4y       no      yes
# 33933   71        retired   single  university.degree       no      yes
# 3217    31    blue-collar  married           basic.6y  unknown  unknown
# 15195   57  self-employed  married  university.degree       no       no
# 3213    44     management   single  university.degree  unknown      yes
# 33937   24         admin.   single  university.degree       no      yes
# 12095   34         admin.  married        high.school       no       no
# 3223    45     technician  married  university.degree       no      yes
#
#           loan    contact month day_of_week  campaign  pdays  previous  \
# 3503       yes  telephone   may         fri         4    999         0
# ...
